# %%
print("This program will predict stock price prediction using XGBoost")
# make sure you have the csv file in the same directory as your python code
# Out:
# This program will predict stock price prediction using XGBoost

# %%
################################ Importing all the packages ##################################

import pandas as pd # getting the pandas package
import xgboost as xgb # the actual ml framework we are using
import matplotlib.pyplot as plt # package to produce graphs
import numpy as np # used to perform mathematical operations on arrays
import os
import time


data = pd.read_csv('TSLA.csv') # make sure the csv file has dataset covering a good amount of years
data # shows the dataset

data['Close'].plot() # using the close column for our stock price prediction
# Out:
# <Axes: >

# %%
############## Plotting the graph with labels ###################
plt.figure(figsize=(11,8))
plt.title("Telsa Stock Closing Price")
plt.plot(data['Close'])
plt.xlabel('Date')
plt.ylabel("Closing Price")
plt.show()

# %%
data = data[["Close"]] # close column
data['target'] = data.Close.shift(-1)
data # There is a null target value at the last row since it doesn't have a target

data.dropna(inplace = True) # drop null values so that it doesn't affect our model
data


# Split - train and test

def train_test(dataset, ratio ): # these paramters just define what will happen if the user calls the function
  dataset = dataset.values
  split_data = int(len(dataset) * (1-ratio)) # ratio indicates that ratio of the data will be used for testing
  return dataset[:split_data], dataset[split_data:]
# Out:
# <ipython-input-5-813a2962a365>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['target'] = data.Close.shift(-1)
# <ipython-input-5-813a2962a365>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace = True) # drop null values so that it doesn't affect our model

# %%
train, test = train_test(data, 0.2) # split into 80% for training, 20% for testing

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error

def predict(train, value):

  train = np.array(train)
  X = train[:, :-1] # selects all rows of the close column from the train data
  Y = train[:, -1] # Selects all rows of the target column from the train data

  param_grid = {"n_estimators": [900, 1000, 1100, 1200, 1300, 1400, 1500],
              "learning_rate": [0.040, 0.045, 0.050, 0.055, 0.060, 0.065, 0.070]}

  search = GridSearchCV(XGBRegressor(objective="reg:squarederror"), param_grid, cv=5)
  search.fit(X, Y)

  print("The best hyperparameters are ",search.best_params_)

  # Update counts of hyperparameters
  update_hyperparam_counts(search.best_params_)

  # Use the best hyperparameters found by grid search
  best_n_estimators = search.best_params_['n_estimators']
  best_learning_rate = search.best_params_['learning_rate']

  model = XGBRegressor(objective="reg:squarederror", n_estimators=best_n_estimators, learning_rate=best_learning_rate)
  model.fit(X,Y)

  value = np.array(value).reshape(1, -1)
  predict = model.predict(value)
  return predict[0]


def validate(dataset, ratio):

  predictions = []
  train, test = train_test(dataset, ratio)

  history = [x for x in train]

  for i in range(len(test)):

    test_X, test_Y = test[i, :-1], test[i, -1]
    prediction = predict(history, test_X[0])
    predictions.append(prediction)
    history.append(test[i])

  error = mean_squared_error(test[:, -1], predictions, squared = False)

  return error, test[:, -1], predictions

hyperparam_counts = {}

def update_hyperparam_counts(params):
    global hyperparam_counts
    key = tuple(params.items())
    hyperparam_counts[key] = hyperparam_counts.get(key, 0) + 1


rmse, y, pred = validate(data, 0.2)
print(rmse)

plt.figure(figsize=(11, 8))
plt.plot(y, label='Actual', color='blue')
plt.plot(pred, label='Predicted', color='red')
plt.xlabel('Index')
plt.ylabel('Stock Price')
plt.title('Actual vs. Predicted Stock Prices')
plt.legend()
plt.show()
# Out:
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.04, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.04, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.04, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.04, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.04, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.04, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.04, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.04, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.04, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.04, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.04, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.04, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.04, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.04, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.04, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.04, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.04, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.045, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.055, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 900}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1300}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.05, 'n_estimators': 1400}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1500}
# The best hyperparameters are  {'learning_rate': 0.06, 'n_estimators': 1100}
# The best hyperparameters are  {'learning_rate': 0.065, 'n_estimators': 1000}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1200}
# The best hyperparameters are  {'learning_rate': 0.07, 'n_estimators': 1000}
